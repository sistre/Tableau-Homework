# %%
# Dependencies
import pandas as pd

# %%
# Read in the 2018 Jersey City Citi Bike CSVs as Data Frames
df2018 = pd.read_csv("JC-201801-citibike-tripdata.csv")
df2018_2 = pd.read_csv("JC-201802-citibike-tripdata.csv")
df2018_3 = pd.read_csv("JC-201803-citibike-tripdata.csv")
df2018_4 = pd.read_csv("JC-201804-citibike-tripdata.csv")
df2018_5 = pd.read_csv("JC-201805-citibike-tripdata.csv")
df2018_6 = pd.read_csv("JC-201806-citibike-tripdata.csv")
df2018_7 = pd.read_csv("JC-201807-citibike-tripdata.csv")
df2018_8 = pd.read_csv("JC-201808-citibike-tripdata.csv")
df2018_9 = pd.read_csv("JC-201809-citibike-tripdata.csv")
df2018_10 = pd.read_csv("JC-201810-citibike-tripdata.csv")
df2018_11 = pd.read_csv("JC-201811-citibike-tripdata.csv")
df2018_12 = pd.read_csv("JC-201812-citibike-tripdata.csv")

# %%
# Combine the 2018 data frames
df2018 = df2018.append(df2018_2, ignore_index=True)
df2018 = df2018.append(df2018_3, ignore_index=True)
df2018 = df2018.append(df2018_4, ignore_index=True)
df2018 = df2018.append(df2018_5, ignore_index=True)
df2018 = df2018.append(df2018_6, ignore_index=True)
df2018 = df2018.append(df2018_7, ignore_index=True)
df2018 = df2018.append(df2018_8, ignore_index=True)
df2018 = df2018.append(df2018_9, ignore_index=True)
df2018 = df2018.append(df2018_10, ignore_index=True)
df2018 = df2018.append(df2018_11, ignore_index=True)
df2018 = df2018.append(df2018_12, ignore_index=True)

# %%
df2018
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1                550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2                510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3                354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4                250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...              ...                       ...                       ...
# 353887          1081  2018-12-22 11:51:46.0600  2018-12-22 12:09:47.4730
# 353888           344  2018-12-25 21:40:09.8660  2018-12-25 21:45:54.2670
# 353889          1233  2018-12-29 12:55:45.9690  2018-12-29 13:16:19.5960
# 353890          1057  2018-12-30 15:32:09.3320  2018-12-30 15:49:46.3510
# 353891           301  2018-12-31 16:34:11.9340  2018-12-31 16:39:13.8340
#
#         start station id start station name  start station latitude  \
# ...

# %%
# Read in the 2019 Jersey City Citi Bike CSVs as Data Frames
df2019 = pd.read_csv("JC-201901-citibike-tripdata.csv")
df2019_2 = pd.read_csv("JC-201902-citibike-tripdata.csv")
df2019_3 = pd.read_csv("JC-201903-citibike-tripdata.csv")
df2019_4 = pd.read_csv("JC-201904-citibike-tripdata.csv")
df2019_5 = pd.read_csv("JC-201905-citibike-tripdata.csv")
df2019_6 = pd.read_csv("JC-201906-citibike-tripdata.csv")
df2019_7 = pd.read_csv("JC-201907-citibike-tripdata.csv")
df2019_8 = pd.read_csv("JC-201908-citibike-tripdata.csv")
df2019_9 = pd.read_csv("JC-201909-citibike-tripdata.csv")
df2019_10 = pd.read_csv("JC-201910-citibike-tripdata.csv")
df2019_11 = pd.read_csv("JC-201911-citibike-tripdata.csv")
df2019_12 = pd.read_csv("JC-201912-citibike-tripdata.csv")

# %%
# Combine the 2019 data frames
df2019 = df2019.append(df2019_2, ignore_index=True)
df2019 = df2019.append(df2019_3, ignore_index=True)
df2019 = df2019.append(df2019_4, ignore_index=True)
df2019 = df2019.append(df2019_5, ignore_index=True)
df2019 = df2019.append(df2019_6, ignore_index=True)
df2019 = df2019.append(df2019_7, ignore_index=True)
df2019 = df2019.append(df2019_8, ignore_index=True)
df2019 = df2019.append(df2019_9, ignore_index=True)
df2019 = df2019.append(df2019_10, ignore_index=True)
df2019 = df2019.append(df2019_11, ignore_index=True)
df2019 = df2019.append(df2019_12, ignore_index=True)

# %%
df2019
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1                505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2                756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3               1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4               1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...              ...                       ...                       ...
# 404942           283  2019-12-31 23:12:18.5480  2019-12-31 23:17:01.8740
# 404943           267  2019-12-31 23:19:03.5840  2019-12-31 23:23:30.6640
# 404944           379  2019-12-31 23:19:06.5830  2019-12-31 23:25:25.7970
# 404945           188  2019-12-31 23:24:00.2630  2019-12-31 23:27:09.0400
# 404946           326  2019-12-31 23:45:20.9780  2019-12-31 23:50:47.7490
#
#         start station id start station name  start station latitude  \
# ...

# %%
# Read in the 2020 Jersey City Citi Bike CSVs as Data Frames
df2020 = pd.read_csv("JC-202001-citibike-tripdata.csv")
df2020_2 = pd.read_csv("JC-202002-citibike-tripdata.csv")
df2020_3 = pd.read_csv("JC-202003-citibike-tripdata.csv")
df2020_4 = pd.read_csv("JC-202004-citibike-tripdata.csv")
df2020_5 = pd.read_csv("JC-202005-citibike-tripdata.csv")
df2020_6 = pd.read_csv("JC-202006-citibike-tripdata.csv")
df2020_7 = pd.read_csv("JC-202007-citibike-tripdata.csv")
df2020_8 = pd.read_csv("JC-202008-citibike-tripdata.csv")
df2020_9 = pd.read_csv("JC-202009-citibike-tripdata.csv")
df2020_10 = pd.read_csv("JC-202010-citibike-tripdata.csv")
df2020_11 = pd.read_csv("JC-202011-citibike-tripdata.csv")
df2020_12 = pd.read_csv("JC-202012-citibike-tripdata.csv")

# %%
# Combine the 2020 data frames
df2020 = df2020.append(df2020_2, ignore_index=True)
df2020 = df2020.append(df2020_3, ignore_index=True)
df2020 = df2020.append(df2020_4, ignore_index=True)
df2020 = df2020.append(df2020_5, ignore_index=True)
df2020 = df2020.append(df2020_6, ignore_index=True)
df2020 = df2020.append(df2020_7, ignore_index=True)
df2020 = df2020.append(df2020_8, ignore_index=True)
df2020 = df2020.append(df2020_9, ignore_index=True)
df2020 = df2020.append(df2020_10, ignore_index=True)
df2020 = df2020.append(df2020_11, ignore_index=True)
df2020 = df2020.append(df2020_12, ignore_index=True)

# %%
df2020
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1                377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2                288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3                435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4                231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...              ...                       ...                       ...
# 336797          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 336798          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 336799          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 336800           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 336801          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id start station name  start station latitude  \
# ...

# %%
#Combine the data for 2018-2020
df2018to2020 = df2018.append(df2019, ignore_index=True)
df2018to2020 = df2018to2020.append(df2020, ignore_index=True)

# %%
df2018to2020
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1                 550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2                 510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3                 354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4                 250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...               ...                       ...                       ...
# 1095636          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 1095637          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 1095638          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 1095639           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 1095640          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#          start station id start station name  start station latitude  \
# ...

# %%
df2018to2020.to_csv("2018-2020_JC-citibike-tripdata.csv", index=False)

# %%
dftest = pd.read_csv("2018-2020_JC-citibike-tripdata.csv")
dftest
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1                 550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2                 510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3                 354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4                 250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...               ...                       ...                       ...
# 1095636          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 1095637          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 1095638          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 1095639           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 1095640          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#          start station id start station name  start station latitude  \
# ...
